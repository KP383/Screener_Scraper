# %%
import numpy as np
import pandas as pd

# %%
main_data = pd.read_csv('main_data.csv')

# %%
main_data = main_data.drop('Unnamed: 0', axis=1)

# %%
main_data[main_data['Marketcap'] < main_data['Sales']]
# Out:
#                              Company Name Company Symbol  Marketcap  \
# 10    Life Insurance Corporation Of India           LICI     369728
# 28                      JSW Steel Limited       JSWSTEEL     165591
# 29  Oil & Natural Gas Corporation Limited           ONGC     194868
# 31                           NTPC Limited           NTPC     165813
# 35                     Tata Steel Limited      TATASTEEL     134218
# 39                    Tata Motors Limited     TATAMOTORS     153221
# 42                        Vedanta Limited           VEDL     109453
# 43              Grasim Industries Limited         GRASIM     103706
# 44         Indian Oil Corporation Limited            IOC     109157
# 45            Hindalco Industries Limited       HINDALCO      93272
# 52                         Bank of Baroda     BANKBARODA      79924
# 62                   Adani Wilmar Limited            AWL      47051
# 65   Bharat Petroleum Corporation Limited           BPCL      68852
# ...
