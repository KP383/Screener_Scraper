# %%
import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import random

# %%
stocks = pd.read_csv('all_stock_data.csv')
stocks
# Out:
#          Symbol                               Company Name  \
# 0      RELIANCE                Reliance Industries Limited
# 1           TCS          Tata Consultancy Services Limited
# 2      HDFCBANK                          HDFC Bank Limited
# 3          INFY                            Infosys Limited
# 4     ICICIBANK                         ICICI Bank Limited
# ...         ...                                        ...
# 2108   VIDEOIND                Videocon Industries Limited
# 2109   VISUINTL                 Visu International Limited
# 2110    WINSOME                      Winsome Yarns Limited
# 2111        WSI                 W S Industries (I) Limited
# 2112      ZICOM  Zicom Electronic Security Systems Limited
#
#      Market capitalization as on December 30, 2022\n(Rs in Lakhs)  \
# 0                                      172329584.148608
# 1                                    119164326.06449099
# 2                                       90797942.979974
# ...

# %%
driver = webdriver.Chrome()

driver.get('https://www.screener.in/login/?')

email_input = driver.find_element(By.XPATH, '//*[@id="id_username"]')
email_input.send_keys('kalathiaparth@gmail.com')
password_input = driver.find_element(By.XPATH, '//*[@id="id_password"]')
password_input.send_keys('P@rth383msm')
submit_button = driver.find_element(By.XPATH, '/html/body/main/div[2]/div[2]/form/button')
submit_button.click()

for i in range(1, 2113):
    
    if i % 501 == 0 and i != 0:
        time.sleep(random.randint(100,150))
    response = driver.get('https://www.screener.in/company/' + stocks['Symbol'][i] + '/consolidated/')
    time.sleep(3)
    driver.refresh()
    time.sleep(2)
    page_source = driver.page_source
    with open(f"/Users/parthkalathia/Desktop/market_watch/Stock_Data_NSE/{stocks['Symbol'][i]}.txt", "w", encoding="utf-8") as f:
        f.write(page_source)
    
    time.sleep(2)
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/rq/rl4qmvpx22jg0wx1l021ysr80000gn/T/ipykernel_2344/3418575146.py in <module>
#      14     if i % 501 == 0 and i != 0:
#      15         time.sleep(random.randint(100,150))
# ---> 16     response = driver.get('https://www.screener.in/company/' + stocks['Symbol'][i] + '/consolidated/')
#      17     time.sleep(3)
#      18     driver.refresh()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     447     def get(self, url: str) -> None:
#     448         """Loads a web page in the current browser session."""
# --> 449         self.execute(Command.GET, {"url": url})
#     450
#     451     @property
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
# ...
